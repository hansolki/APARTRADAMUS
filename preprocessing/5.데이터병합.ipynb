# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 파일 경로 설정
file_path = '/content/drive/MyDrive/2조/Database/종속변수/train_data/data(ver.4.3)_한솔.csv'

# 파일 읽어오기
import pandas as pd
df = pd.read_csv(file_path, index_col=0)
df.head()
# Out:
#    지역구  동  건축연도  계약연도  계약월  계약일   층  전용면적(㎡)  공공체육시설(개소)  공원면적(천㎡)  ...  \
# 0    0  8  1996  2022    2    8   4   197.91         293    7794.1  ...
# 1    0  8  1996  2015   12   23   1   197.91         278    6422.0  ...
# 2    0  8  1984  2021    2    7  14   186.16         292    7791.3  ...
# 3    0  8  1984  2017    5    5  14   186.16         278    6591.7  ...
# 4    0  8  1984  2015    4   12  13   186.16         278    6422.0  ...
#
#    흡연률(%)  월간음주율(%)  비만율(%)  연간출산율(%)  인플루엔자 접종률(%)  건강생활실천율(%)  등록외국인현황(명)  \
# 0    11.8      5001    25.9     0.490          47.9        49.4        5001
# 1    18.2      5265    22.6     0.857          31.8        40.5        5265
# 2    11.3      4758    22.5     0.523          46.7        41.6        4758
# 3    16.1      4888    22.4     0.706          36.1        48.4        4888
# 4    18.2      5265    22.6     0.857          31.8        40.5        5265
#
#    지역구별 다문화가구(가구)  지역구별 다문화가구원(명)  거래금액(만원)
# ...

# %%
df1 = pd.read_csv('/content/drive/MyDrive/2조/Database/종속변수/train_data/data(ver.2)_한솔.csv', index_col=0)
df1.head()
# Out:
#        동             단지명  전용면적(㎡)  층  건축년도   계약년  계약월  계약일 거래금액(만원)
# 지역구
# 강남구  개포동  개포2차현대아파트(220)    77.75  5  1988  2015    1   11   60,000
# 강남구  개포동  개포2차현대아파트(220)    77.75  5  1988  2015    3    3   65,000
# 강남구  개포동  개포2차현대아파트(220)    77.75  2  1988  2015    3    7   62,500
# 강남구  개포동  개포2차현대아파트(220)    77.75  6  1988  2015    8   16   68,000
# 강남구  개포동  개포6차우성아파트1동~8동    79.97  5  1987  2015    1   29   73,000

# %%
print(df1.shape)
print(df2.shape)
# Out:
# (666251, 9)
# (200, 24)

# %%
df2 = pd.read_csv('/content/drive/MyDrive/2조/Database/독립변수/한솔/통합본(초등학교,고등학교,학원수,범죄건수,접종률,경제지표,경제성장률).csv', index_col=0)
df2.head()
# Out:
#    지역구    연도  초등학교 수  고등학교 수  학원 수  범죄건수  인플루엔자 접종률  소비자물가지수(2020=100)  \
# 0  종로구  2015      14      15    97  4705       33.7              94.47
# 1   중구  2015      12      12    60  4954       31.0              94.47
# 2  용산구  2015      15      10   129  3820       34.7              94.47
# 3  성동구  2015      20       7   240  3358       34.0              94.47
# 4  광진구  2015      22       9   389  5909       33.1              94.47
#
#    예금은행대출금액(십억원)  예금은행예금액(십억원)  소비자물가 등락률(%)  임금상승률(%)  청년고용률(%)  실업률(시도)  \
# 0       525529.0      600391.0           1.3       1.9      43.8      4.2
# 1       525529.0      600391.0           1.3       1.9      43.8      4.2
# 2       525529.0      600391.0           1.3       1.9      43.8      4.2
# 3       525529.0      600391.0           1.3       1.9      43.8      4.2
# 4       525529.0      600391.0           1.3       1.9      43.8      4.2
#
#    실업자수(천명)  취업자증감(천명)  청년실업률(%)  제조업생산 증감률(%)  서비스업생산 증감률(%)  수입액(100만달러)  \
# ...

# %%
df2.columns
# Out:
# Index(['지역구', '연도', '초등학교 수', '고등학교 수', '학원 수', '범죄건수', '인플루엔자 접종률',
#        '소비자물가지수(2020=100)', '예금은행대출금액(십억원)', '예금은행예금액(십억원)', '소비자물가 등락률(%)',
#        '임금상승률(%)', '청년고용률(%)', '실업률(시도)', '실업자수(천명)', '취업자증감(천명)', '청년실업률(%)',
#        '제조업생산 증감률(%)', '서비스업생산 증감률(%)', '수입액(100만달러)', '수출액(100만달러)',
#        '지방세(백만원)', '국내총생산(명목GDP)', '경제성장률(실질GDP성장률)'],
#       dtype='object')

# %%
df2.columns = ['지역구', '계약년', '초등학교 수', '고등학교 수', '학원 수', '범죄건수', '인플루엔자 접종률',
       '소비자물가지수(2020=100)', '예금은행대출금액(십억원)', '예금은행예금액(십억원)', '소비자물가 등락률(%)',
       '임금상승률(%)', '청년고용률(%)', '실업률(시도)', '실업자수(천명)', '취업자증감(천명)', '청년실업률(%)',
       '제조업생산 증감률(%)', '서비스업생산 증감률(%)', '수입액(100만달러)', '수출액(100만달러)',
       '지방세(백만원)', '국내총생산(명목GDP)', '경제성장률(실질GDP성장률)']

df2.columns
# Out:
# Index(['지역구', '계약년', '초등학교 수', '고등학교 수', '학원 수', '범죄건수', '인플루엔자 접종률',
#        '소비자물가지수(2020=100)', '예금은행대출금액(십억원)', '예금은행예금액(십억원)', '소비자물가 등락률(%)',
#        '임금상승률(%)', '청년고용률(%)', '실업률(시도)', '실업자수(천명)', '취업자증감(천명)', '청년실업률(%)',
#        '제조업생산 증감률(%)', '서비스업생산 증감률(%)', '수입액(100만달러)', '수출액(100만달러)',
#        '지방세(백만원)', '국내총생산(명목GDP)', '경제성장률(실질GDP성장률)'],
#       dtype='object')

# %%
df2.head()
# Out:
#    지역구   계약년  초등학교 수  고등학교 수  학원 수  범죄건수  인플루엔자 접종률  소비자물가지수(2020=100)  \
# 0  종로구  2015      14      15    97  4705       33.7              94.47
# 1   중구  2015      12      12    60  4954       31.0              94.47
# 2  용산구  2015      15      10   129  3820       34.7              94.47
# 3  성동구  2015      20       7   240  3358       34.0              94.47
# 4  광진구  2015      22       9   389  5909       33.1              94.47
#
#    예금은행대출금액(십억원)  예금은행예금액(십억원)  소비자물가 등락률(%)  임금상승률(%)  청년고용률(%)  실업률(시도)  \
# 0       525529.0      600391.0           1.3       1.9      43.8      4.2
# 1       525529.0      600391.0           1.3       1.9      43.8      4.2
# 2       525529.0      600391.0           1.3       1.9      43.8      4.2
# 3       525529.0      600391.0           1.3       1.9      43.8      4.2
# 4       525529.0      600391.0           1.3       1.9      43.8      4.2
#
#    실업자수(천명)  취업자증감(천명)  청년실업률(%)  제조업생산 증감률(%)  서비스업생산 증감률(%)  수입액(100만달러)  \
# ...

# %%
df1 = pd.merge(left=df1, right=df2, on=['지역구', '계약년'])

# %%
df1.head()
# Out:
#    지역구    동             단지명  전용면적(㎡)  층  건축년도   계약년  계약월  계약일 거래금액(만원)  \
# 0  강남구  개포동  개포2차현대아파트(220)    77.75  5  1988  2015    1   11   60,000
# 1  강남구  개포동  개포2차현대아파트(220)    77.75  5  1988  2015    3    3   65,000
# 2  강남구  개포동  개포2차현대아파트(220)    77.75  2  1988  2015    3    7   62,500
# 3  강남구  개포동  개포2차현대아파트(220)    77.75  6  1988  2015    8   16   68,000
# 4  강남구  개포동  개포6차우성아파트1동~8동    79.97  5  1987  2015    1   29   73,000
#
#    초등학교 수  고등학교 수  학원 수  범죄건수  인플루엔자 접종률  소비자물가지수(2020=100)  예금은행대출금액(십억원)  \
# 0      33      21  1688  8617       31.8              94.47       525529.0
# 1      33      21  1688  8617       31.8              94.47       525529.0
# 2      33      21  1688  8617       31.8              94.47       525529.0
# 3      33      21  1688  8617       31.8              94.47       525529.0
# 4      33      21  1688  8617       31.8              94.47       525529.0
#
#    예금은행예금액(십억원)  소비자물가 등락률(%)  임금상승률(%)  청년고용률(%)  실업률(시도)  실업자수(천명)  \
# ...

# %%
df2 = pd.read_csv('/content/drive/MyDrive/2조/Database/독립변수/성은/건강생활실천율.csv', index_col=0)
df2.head(10)

# df2.columns = ['2015 건강생활실천율', '2016 건강생활실천율', '2017 건강생활실천율', '2018 건강생활실천율', '2019 건강생활실천율', '2020 건강생활실천율', '2021 건강생활실천율', '2022 건강생활실천율']
df2 = df2.reset_index()
df2
# Out:
#      지역구  2015  2016  2017  2018  2019  2020  2021  2022
# 0    강남구  40.5  38.2  48.4  40.1  45.1  33.7  41.6  49.4
# 1    강동구  38.7  32.8  46.2  54.3  38.4  35.5  47.6  48.6
# 2    강북구  39.8  30.4  34.2  41.1  41.7  37.2  40.0  40.4
# 3    강서구  38.5  37.2  37.9  45.0  43.1  33.9  47.2  47.8
# 4    관악구  39.0  46.6  52.5  48.1  45.8  41.3  43.1  41.8
# 5    광진구  43.7  38.9  46.2  40.6  43.1  41.9  42.0  49.0
# 6    구로구  47.4  37.6  47.8  52.2  46.3  33.5  49.4  48.3
# 7    금천구  32.3  34.8  38.9  47.8  44.0  38.5  36.2  38.7
# 8    노원구  31.7  31.3  35.4  49.8  44.8  54.6  51.2  54.5
# 9    도봉구  35.0  32.6  30.5  43.2  40.5  36.2  38.4  48.8
# 10  동대문구  46.6  46.9  38.6  47.6  34.5  41.8  44.5  51.4
# 11   동작구  45.0  47.4  47.8  50.0  49.5  36.7  41.0  44.7
# 12   마포구  43.2  45.4  53.8  50.0  45.1  36.6  44.7  43.2
# 13  서대문구  33.0  42.9  42.3  58.0  38.0  48.9  38.3  42.7
# 14   서초구  42.0  40.8  46.5  49.3  45.0  39.3  45.4  52.4
# ...

# %%
#df1에 '공공체육시설'이라는 칼럼을 추가하고, df2의 연도별, 지역구 조건에 맞는 데이터를 해당 칼럼에 넣는 함수
def add(df1, df2):
    # df2의 연도 열 이름을 리스트로 변환
    years = df2.columns[1:]

    # df2를 녹여서 각 지역구의 연도별 공공체육시설 수를 단일 열로 만듦
    df2_melted = df2.melt(id_vars=['지역구'], value_vars=years, var_name='계약년', value_name='건강생활실천율')
    df2_melted['계약년'] = df2_melted['계약년'].astype(int)  # 계약년 형변환

    # df1과 df2_melted를 '지역구'와 '계약년'을 기준으로 병합
    df1_merged = pd.merge(df1, df2_melted, on=['지역구', '계약년'], how='left')

    return df1_merged

#함수 실행
df1_updated = add(df1, df2)

#결과의 처음 몇 행 확인
df1_updated.head()
# Out:
#    지역구    동             단지명  전용면적(㎡)  층  건축년도   계약년  계약월  계약일 거래금액(만원)  \
# 0  강남구  개포동  개포2차현대아파트(220)    77.75  5  1988  2015    1   11   60,000
# 1  강남구  개포동  개포2차현대아파트(220)    77.75  5  1988  2015    3    3   65,000
# 2  강남구  개포동  개포2차현대아파트(220)    77.75  2  1988  2015    3    7   62,500
# 3  강남구  개포동  개포2차현대아파트(220)    77.75  6  1988  2015    8   16   68,000
# 4  강남구  개포동  개포6차우성아파트1동~8동    79.97  5  1987  2015    1   29   73,000
#
#    초등학교 수  고등학교 수  학원 수  범죄건수  인플루엔자 접종률  소비자물가지수(2020=100)  예금은행대출금액(십억원)  \
# 0      33      21  1688  8617       31.8              94.47       525529.0
# 1      33      21  1688  8617       31.8              94.47       525529.0
# 2      33      21  1688  8617       31.8              94.47       525529.0
# 3      33      21  1688  8617       31.8              94.47       525529.0
# 4      33      21  1688  8617       31.8              94.47       525529.0
#
#    예금은행예금액(십억원)  소비자물가 등락률(%)  임금상승률(%)  청년고용률(%)  실업률(시도)  실업자수(천명)  \
# ...

# %%
df1 = df1_updated

# %%
df2 = pd.read_csv('/content/drive/MyDrive/2조/Database/독립변수/성은/년간출산율.csv', index_col=0)
df2.head(10)

df2 = df2.reset_index()
df2
# Out:
#      지역구   2015   2016   2017   2018   2019   2020   2021   2022
# 0    종로구  0.813  0.784  0.646  0.606  0.648  0.522  0.531  0.477
# 1     중구  0.946  0.974  0.824  0.737  0.780  0.688  0.634  0.606
# 2    용산구  1.005  0.907  0.793  0.747  0.713  0.634  0.664  0.596
# 3    성동구  1.095  1.013  0.972  0.909  0.855  0.783  0.764  0.723
# 4    광진구  0.903  0.867  0.749  0.713  0.652  0.527  0.525  0.461
# 5   동대문구  0.960  0.889  0.822  0.753  0.765  0.699  0.660  0.620
# 6    중랑구  1.051  0.995  0.906  0.825  0.777  0.660  0.650  0.659
# 7    성북구  0.991  0.909  0.818  0.737  0.707  0.676  0.656  0.649
# 8    강북구  0.922  0.878  0.825  0.647  0.617  0.550  0.541  0.483
# 9    도봉구  1.010  0.947  0.833  0.774  0.697  0.601  0.579  0.573
# 10   노원구  1.096  1.068  0.938  0.809  0.776  0.695  0.701  0.716
# 11   은평구  1.003  0.943  0.814  0.772  0.697  0.623  0.604  0.613
# 12  서대문구  0.913  0.934  0.823  0.727  0.685  0.685  0.635  0.607
# ...

# %%
#df1에 '공공체육시설'이라는 칼럼을 추가하고, df2의 연도별, 지역구 조건에 맞는 데이터를 해당 칼럼에 넣는 함수
def add(df1, df2):
    # df2의 연도 열 이름을 리스트로 변환
    years = df2.columns[1:]

    # df2를 녹여서 각 지역구의 연도별 공공체육시설 수를 단일 열로 만듦
    df2_melted = df2.melt(id_vars=['지역구'], value_vars=years, var_name='계약년', value_name='연간출산률')
    df2_melted['계약년'] = df2_melted['계약년'].astype(int)  # 계약년 형변환

    # df1과 df2_melted를 '지역구'와 '계약년'을 기준으로 병합
    df1_merged = pd.merge(df1, df2_melted, on=['지역구', '계약년'], how='left')

    return df1_merged

#함수 실행
df1 = add(df1, df2)

#결과의 처음 몇 행 확인
df1.head()
# Out:
#    지역구    동             단지명  전용면적(㎡)  층  건축년도   계약년  계약월  계약일 거래금액(만원)  \
# 0  강남구  개포동  개포2차현대아파트(220)    77.75  5  1988  2015    1   11   60,000
# 1  강남구  개포동  개포2차현대아파트(220)    77.75  5  1988  2015    3    3   65,000
# 2  강남구  개포동  개포2차현대아파트(220)    77.75  2  1988  2015    3    7   62,500
# 3  강남구  개포동  개포2차현대아파트(220)    77.75  6  1988  2015    8   16   68,000
# 4  강남구  개포동  개포6차우성아파트1동~8동    79.97  5  1987  2015    1   29   73,000
#
#    초등학교 수  고등학교 수  학원 수  범죄건수  인플루엔자 접종률  소비자물가지수(2020=100)  예금은행대출금액(십억원)  \
# 0      33      21  1688  8617       31.8              94.47       525529.0
# 1      33      21  1688  8617       31.8              94.47       525529.0
# 2      33      21  1688  8617       31.8              94.47       525529.0
# 3      33      21  1688  8617       31.8              94.47       525529.0
# 4      33      21  1688  8617       31.8              94.47       525529.0
#
#    예금은행예금액(십억원)  소비자물가 등락률(%)  임금상승률(%)  청년고용률(%)  실업률(시도)  실업자수(천명)  \
# ...

# %%
df2 = pd.read_csv('/content/drive/MyDrive/2조/Database/독립변수/성은/노인여가복지시설.csv', index_col=0)
df2.head(10)

df2 = df2.reset_index()
df2

#df1에 '공공체육시설'이라는 칼럼을 추가하고, df2의 연도별, 지역구 조건에 맞는 데이터를 해당 칼럼에 넣는 함수
def add(df1, df2):
    # df2의 연도 열 이름을 리스트로 변환
    years = df2.columns[1:]

    # df2를 녹여서 각 지역구의 연도별 공공체육시설 수를 단일 열로 만듦
    df2_melted = df2.melt(id_vars=['지역구'], value_vars=years, var_name='계약년', value_name='노인여가복지시설')
    df2_melted['계약년'] = df2_melted['계약년'].astype(int)  # 계약년 형변환

    # df1과 df2_melted를 '지역구'와 '계약년'을 기준으로 병합
    df1_merged = pd.merge(df1, df2_melted, on=['지역구', '계약년'], how='left')

    return df1_merged

#함수 실행
df1 = add(df1, df2)

#결과의 처음 몇 행 확인
df1.head()
# Out:
#    지역구    동             단지명  전용면적(㎡)  층  건축년도   계약년  계약월  계약일 거래금액(만원)  \
# 0  강남구  개포동  개포2차현대아파트(220)    77.75  5  1988  2015    1   11   60,000
# 1  강남구  개포동  개포2차현대아파트(220)    77.75  5  1988  2015    3    3   65,000
# 2  강남구  개포동  개포2차현대아파트(220)    77.75  2  1988  2015    3    7   62,500
# 3  강남구  개포동  개포2차현대아파트(220)    77.75  6  1988  2015    8   16   68,000
# 4  강남구  개포동  개포6차우성아파트1동~8동    79.97  5  1987  2015    1   29   73,000
#
#    초등학교 수  고등학교 수  학원 수  범죄건수  인플루엔자 접종률  소비자물가지수(2020=100)  예금은행대출금액(십억원)  \
# 0      33      21  1688  8617       31.8              94.47       525529.0
# 1      33      21  1688  8617       31.8              94.47       525529.0
# 2      33      21  1688  8617       31.8              94.47       525529.0
# 3      33      21  1688  8617       31.8              94.47       525529.0
# 4      33      21  1688  8617       31.8              94.47       525529.0
#
#    예금은행예금액(십억원)  소비자물가 등락률(%)  임금상승률(%)  청년고용률(%)  실업률(시도)  실업자수(천명)  \
# ...

# %%
df2 = pd.read_csv('/content/drive/MyDrive/2조/Database/독립변수/성은/등록외국인현황_구별.csv', index_col=0)
df2.head(10)

df2 = df2.reset_index()
df2

#df1에 '공공체육시설'이라는 칼럼을 추가하고, df2의 연도별, 지역구 조건에 맞는 데이터를 해당 칼럼에 넣는 함수
def add(df1, df2):
    # df2의 연도 열 이름을 리스트로 변환
    years = df2.columns[1:]

    # df2를 녹여서 각 지역구의 연도별 공공체육시설 수를 단일 열로 만듦
    df2_melted = df2.melt(id_vars=['지역구'], value_vars=years, var_name='계약년', value_name='등록외국인현황(명)')
    df2_melted['계약년'] = df2_melted['계약년'].astype(int)  # 계약년 형변환

    # df1과 df2_melted를 '지역구'와 '계약년'을 기준으로 병합
    df1_merged = pd.merge(df1, df2_melted, on=['지역구', '계약년'], how='left')

    return df1_merged

#함수 실행
df1 = add(df1, df2)

#결과의 처음 몇 행 확인
df1.head()
# Out:
#    지역구    동             단지명  전용면적(㎡)  층  건축년도   계약년  계약월  계약일 거래금액(만원)  \
# 0  강남구  개포동  개포2차현대아파트(220)    77.75  5  1988  2015    1   11   60,000
# 1  강남구  개포동  개포2차현대아파트(220)    77.75  5  1988  2015    3    3   65,000
# 2  강남구  개포동  개포2차현대아파트(220)    77.75  2  1988  2015    3    7   62,500
# 3  강남구  개포동  개포2차현대아파트(220)    77.75  6  1988  2015    8   16   68,000
# 4  강남구  개포동  개포6차우성아파트1동~8동    79.97  5  1987  2015    1   29   73,000
#
#    초등학교 수  고등학교 수  학원 수  범죄건수  인플루엔자 접종률  소비자물가지수(2020=100)  예금은행대출금액(십억원)  \
# 0      33      21  1688  8617       31.8              94.47       525529.0
# 1      33      21  1688  8617       31.8              94.47       525529.0
# 2      33      21  1688  8617       31.8              94.47       525529.0
# 3      33      21  1688  8617       31.8              94.47       525529.0
# 4      33      21  1688  8617       31.8              94.47       525529.0
#
#    예금은행예금액(십억원)  소비자물가 등락률(%)  임금상승률(%)  청년고용률(%)  실업률(시도)  실업자수(천명)  \
# ...

# %%
df2
# Out:
#      지역구   2015   2016   2017   2018   2019   2020   2021   2022
# 0    종로구   8836   9185   9487   9961  10579   9612   9106  10832
# 1     중구   8596   9160   8884   9908  10317   9395   9288  10348
# 2    용산구  14567  14861  15283  16091  16515  14605  14332  14634
# 3    성동구   8062   7902   7903   8242   8090   6949   6682   7234
# 4    광진구  14811  14889  14595  15504  15622  13427  12631  13836
# 5   동대문구  13671  15243  15364  16286  16829  14177  14606  16957
# 6    중랑구   4711   4672   4554   4938   5009   4860   4535   4822
# 7    성북구  10285  11262  11352  11819  12094   9903   9614  11587
# 8    강북구   3553   3509   3523   3751   3741   3514   3381   4042
# 9    도봉구   1999   2052   2068   2236   2269   2104   2007   2295
# 10   노원구   3638   3631   3672   4408   4398   3995   3990   4280
# 11   은평구   4658   4461   4408   4469   4514   4208   3866   3856
# 12  서대문구  10964  11677  12228  12767  13774  10779  10840  13217
# ...

# %%
print(df1['등록외국인현황(명)'].value_counts())
# Out:
# 3638     11740
# 4408     11384
# 3631     10953
# 3672     10024
# 3995      9068
#          ...
# 13836      285
# 4042       275
# 14634      257
# 10348      207
# 10832      172
# Name: 등록외국인현황(명), Length: 199, dtype: int64

# %%
df2.nunique()
# Out:
# 지역구     25
# 2015    25
# 2016    25
# 2017    25
# 2018    25
# 2019    25
# 2020    25
# 2021    25
# 2022    25
# dtype: int64

# %%
df1['계약년'].unique()
# Out:
# array([2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022])

# %%
print(df1['등록외국인현황(명)'].nunique())

df2.nunique().sum() - df2['지역구'].nunique()
# Out:
# 199
# 200

# %%
df2 = pd.read_csv('/content/drive/MyDrive/2조/Database/독립변수/성은/비만율.csv', index_col=0)
df2.head(10)

df2 = df2.reset_index()
df2

#df1에 '공공체육시설'이라는 칼럼을 추가하고, df2의 연도별, 지역구 조건에 맞는 데이터를 해당 칼럼에 넣는 함수
def add(df1, df2):
    # df2의 연도 열 이름을 리스트로 변환
    years = df2.columns[1:]

    # df2를 녹여서 각 지역구의 연도별 공공체육시설 수를 단일 열로 만듦
    df2_melted = df2.melt(id_vars=['지역구'], value_vars=years, var_name='계약년', value_name='비만율(%)')
    df2_melted['계약년'] = df2_melted['계약년'].astype(int)  # 계약년 형변환

    # df1과 df2_melted를 '지역구'와 '계약년'을 기준으로 병합
    df1_merged = pd.merge(df1, df2_melted, on=['지역구', '계약년'], how='left')

    return df1_merged

#함수 실행
df1 = add(df1, df2)

#결과의 처음 몇 행 확인
df1.head()
# Out:
#    지역구    동             단지명  전용면적(㎡)  층  건축년도   계약년  계약월  계약일 거래금액(만원)  \
# 0  강남구  개포동  개포2차현대아파트(220)    77.75  5  1988  2015    1   11   60,000
# 1  강남구  개포동  개포2차현대아파트(220)    77.75  5  1988  2015    3    3   65,000
# 2  강남구  개포동  개포2차현대아파트(220)    77.75  2  1988  2015    3    7   62,500
# 3  강남구  개포동  개포2차현대아파트(220)    77.75  6  1988  2015    8   16   68,000
# 4  강남구  개포동  개포6차우성아파트1동~8동    79.97  5  1987  2015    1   29   73,000
#
#    초등학교 수  고등학교 수  학원 수  범죄건수  인플루엔자 접종률  소비자물가지수(2020=100)  예금은행대출금액(십억원)  \
# 0      33      21  1688  8617       31.8              94.47       525529.0
# 1      33      21  1688  8617       31.8              94.47       525529.0
# 2      33      21  1688  8617       31.8              94.47       525529.0
# 3      33      21  1688  8617       31.8              94.47       525529.0
# 4      33      21  1688  8617       31.8              94.47       525529.0
#
#    예금은행예금액(십억원)  소비자물가 등락률(%)  임금상승률(%)  청년고용률(%)  실업률(시도)  실업자수(천명)  \
# ...

# %%
df1['비만율(%)'].nunique(), df2.nunique().sum() - df2['지역구'].nunique()
# Out:
# (111, 181)

# %%
df2.head()
# Out:
#    지역구  2015  2016  2017  2018  2019  2020  2021  2022
# 0  종로구  25.0  26.0  25.8  34.5  34.2  28.1  25.4  27.5
# 1   중구  23.6  25.7  24.5  31.6  29.1  25.6  27.2  25.5
# 2  용산구  24.7  24.0  25.8  30.2  26.5  25.4  26.2  27.2
# 3  성동구  24.1  26.1  26.9  32.8  32.4  28.6  26.3  28.0
# 4  광진구  24.5  26.1  24.7  30.5  28.9  24.6  27.6  31.1

# %%
df2[df2['지역구']=='관악구']
# Out:
#     지역구  2015  2016  2017  2018  2019  2020  2021  2022
# 20  관악구  24.7  25.8  25.5  25.1  35.1  26.6  29.5  31.0

# %%
df1[df1['지역구']=='관악구']['비만율(%)'].unique()
# Out:
# array([24.7, 25.8, 25.5, 25.1, 35.1, 26.6, 29.5, 31. ])

# %%
local_list = df1['지역구'].unique()
for local in local_list:
  print(df2[df2['지역구']==local])
  print(df1[df1['지역구']==local]['비만율(%)'].unique())
  print('--------------------------------------------------')
# Out:
#     지역구  2015  2016  2017  2018  2019  2020  2021  2022
# 22  강남구  22.6  20.3  22.4  27.6  28.6  24.8  22.5  25.9
# [22.6 20.3 22.4 27.6 28.6 24.8 22.5 25.9]
# --------------------------------------------------
#     지역구  2015  2016  2017  2018  2019  2020  2021  2022
# 24  강동구  24.0  30.9  24.2  32.7  31.3  31.3  27.1  28.9
# [24.  30.9 24.2 32.7 31.3 27.1 28.9]
# --------------------------------------------------
#    지역구  2015  2016  2017  2018  2019  2020  2021  2022
# 8  강북구  29.5  29.3  29.6  31.3  30.3  30.3  32.3  33.0
# [29.5 29.3 29.6 31.3 30.3 32.3 33. ]
# --------------------------------------------------
#     지역구  2015  2016  2017  2018  2019  2020  2021  2022
# 15  강서구  24.6  26.8  25.2  34.1  30.7  29.9  29.6  27.7
# [24.6 26.8 25.2 34.1 30.7 29.9 29.6 27.7]
# --------------------------------------------------
#     지역구  2015  2016  2017  2018  2019  2020  2021  2022
# 20  관악구  24.7  25.8  25.5  25.1  35.1  26.6  29.5  31.0
# [24.7 25.8 25.5 25.1 35.1 26.6 29.5 31. ]
# ...

# %%
con1 = df1['지역구'] == '도봉구'
con2 = df1['계약년'] == 2020

df1[con1&con2]
# Out:
#         지역구    동   단지명  전용면적(㎡)   층  건축년도   계약년  계약월  계약일 거래금액(만원)  초등학교 수  \
# 528175  도봉구  도봉동    극동    84.83  10  1991  2020    1   23   37,000      23
# 528176  도봉구  도봉동    극동    84.83   4  1991  2020    2    8   33,000      23
# 528177  도봉구  도봉동    극동    84.83  10  1991  2020    2   22   36,500      23
# 528178  도봉구  도봉동    극동    84.83  11  1991  2020    3    7   34,900      23
# 528179  도봉구  도봉동    극동    84.83  10  1991  2020    3   11   34,200      23
# ...     ...  ...   ...      ...  ..   ...   ...  ...  ...      ...     ...
# 532746  도봉구   창동  현대조합    59.91  14  2000  2020    8   11   54,800      23
# 532747  도봉구   창동  현대조합    59.91  17  2000  2020    9   22   53,800      23
# 532748  도봉구   창동  현대조합    59.91  17  2000  2020    9   22   53,800      23
# 532749  도봉구   창동  현대조합    59.91  17  2000  2020    9   22   53,800      23
# 532750  도봉구   창동  현대조합    59.91  10  2000  2020   12   22   57,800      23
#
# ...

# %%
df2 = pd.read_csv('/content/drive/MyDrive/2조/Database/독립변수/성은/월간음주율.csv', index_col=0)

df2 = df2.reset_index()


#df1에 '공공체육시설'이라는 칼럼을 추가하고, df2의 연도별, 지역구 조건에 맞는 데이터를 해당 칼럼에 넣는 함수
def add(df1, df2):
    # df2의 연도 열 이름을 리스트로 변환
    years = df2.columns[1:]

    # df2를 녹여서 각 지역구의 연도별 공공체육시설 수를 단일 열로 만듬
    df2_melted = df2.melt(id_vars=['지역구'], value_vars=years, var_name='계약년', value_name='월간음주율(%)')
    df2_melted['계약년'] = df2_melted['계약년'].astype(int)  # 계약년 형변환

    # df1과 df2_melted를 '지역구'와 '계약년'을 기준으로 병합
    df1_merged = pd.merge(df1, df2_melted, on=['지역구', '계약년'], how='left')

    return df1_merged

#함수 실행
df1 = add(df1, df2)

#결과의 처음 몇 행 확인
print(df1.isnull().sum())
df1.head()
# Out:
# 지역구                        0
# 동                          0
# 단지명                        0
# 전용면적(㎡)                    0
# 층                          0
# 건축년도                       0
# 계약년                        0
# 계약월                        0
# 계약일                        0
# 거래금액(만원)                   0
# 초등학교 수                     0
# 고등학교 수                     0
# 학원 수                       0
# 범죄건수                       0
# 인플루엔자 접종률                  0
# 소비자물가지수(2020=100)          0
# 예금은행대출금액(십억원)              0
# 예금은행예금액(십억원)               0
# 소비자물가 등락률(%)               0
# 임금상승률(%)                   0
# 청년고용률(%)                   0
# 실업률(시도)                    0
# 실업자수(천명)                   0
# 취업자증감(천명)                  0
# 청년실업률(%)                   0
# 제조업생산 증감률(%)               0
# 서비스업생산 증감률(%)              0
# 수입액(100만달러)                0
# 수출액(100만달러)                0
# 지방세(백만원)                   0
# 국내총생산(명목GDP)               0
# 경제성장률(실질GDP성장률)            0
# ...

# %%
df2 = pd.read_csv('/content/drive/MyDrive/2조/Database/독립변수/성은/지역구별_다문화가구수.csv', index_col=0)

df2 = df2.reset_index()


#df1에 '공공체육시설'이라는 칼럼을 추가하고, df2의 연도별, 지역구 조건에 맞는 데이터를 해당 칼럼에 넣는 함수
def add(df1, df2):
    # df2의 연도 열 이름을 리스트로 변환
    years = df2.columns[1:]

    # df2를 녹여서 각 지역구의 연도별 공공체육시설 수를 단일 열로 만듬
    df2_melted = df2.melt(id_vars=['지역구'], value_vars=years, var_name='계약년', value_name='다문화가구(가구)')
    df2_melted['계약년'] = df2_melted['계약년'].astype(int)  # 계약년 형변환

    # df1과 df2_melted를 '지역구'와 '계약년'을 기준으로 병합
    df1_merged = pd.merge(df1, df2_melted, on=['지역구', '계약년'], how='left')

    return df1_merged

#함수 실행
df1 = add(df1, df2)

#결과의 처음 몇 행 확인
print(df1.isnull().sum().sum())
df1.head()
# Out:
# 0
#    지역구    동             단지명  전용면적(㎡)  층  건축년도   계약년  계약월  계약일 거래금액(만원)  \
# 0  강남구  개포동  개포2차현대아파트(220)    77.75  5  1988  2015    1   11   60,000
# 1  강남구  개포동  개포2차현대아파트(220)    77.75  5  1988  2015    3    3   65,000
# 2  강남구  개포동  개포2차현대아파트(220)    77.75  2  1988  2015    3    7   62,500
# 3  강남구  개포동  개포2차현대아파트(220)    77.75  6  1988  2015    8   16   68,000
# 4  강남구  개포동  개포6차우성아파트1동~8동    79.97  5  1987  2015    1   29   73,000
#
#    초등학교 수  고등학교 수  학원 수  범죄건수  인플루엔자 접종률  소비자물가지수(2020=100)  예금은행대출금액(십억원)  \
# 0      33      21  1688  8617       31.8              94.47       525529.0
# 1      33      21  1688  8617       31.8              94.47       525529.0
# 2      33      21  1688  8617       31.8              94.47       525529.0
# 3      33      21  1688  8617       31.8              94.47       525529.0
# 4      33      21  1688  8617       31.8              94.47       525529.0
#
#    예금은행예금액(십억원)  소비자물가 등락률(%)  임금상승률(%)  청년고용률(%)  실업률(시도)  실업자수(천명)  \
# ...

# %%
df2 = pd.read_csv('/content/drive/MyDrive/2조/Database/독립변수/성은/지역구별_다문화가구원(명).csv', index_col=0)

df2 = df2.reset_index()


#df1에 '공공체육시설'이라는 칼럼을 추가하고, df2의 연도별, 지역구 조건에 맞는 데이터를 해당 칼럼에 넣는 함수
def add(df1, df2):
    # df2의 연도 열 이름을 리스트로 변환
    years = df2.columns[1:]

    # df2를 녹여서 각 지역구의 연도별 공공체육시설 수를 단일 열로 만듬
    df2_melted = df2.melt(id_vars=['지역구'], value_vars=years, var_name='계약년', value_name='다문화가구원(명)')
    df2_melted['계약년'] = df2_melted['계약년'].astype(int)  # 계약년 형변환

    # df1과 df2_melted를 '지역구'와 '계약년'을 기준으로 병합
    df1_merged = pd.merge(df1, df2_melted, on=['지역구', '계약년'], how='left')

    return df1_merged

#함수 실행
df1 = add(df1, df2)

#결과의 처음 몇 행 확인
print(df1.isnull().sum().sum())
df1.head()
# Out:
# 0
#    지역구    동             단지명  전용면적(㎡)  층  건축년도   계약년  계약월  계약일 거래금액(만원)  \
# 0  강남구  개포동  개포2차현대아파트(220)    77.75  5  1988  2015    1   11   60,000
# 1  강남구  개포동  개포2차현대아파트(220)    77.75  5  1988  2015    3    3   65,000
# 2  강남구  개포동  개포2차현대아파트(220)    77.75  2  1988  2015    3    7   62,500
# 3  강남구  개포동  개포2차현대아파트(220)    77.75  6  1988  2015    8   16   68,000
# 4  강남구  개포동  개포6차우성아파트1동~8동    79.97  5  1987  2015    1   29   73,000
#
#    초등학교 수  고등학교 수  학원 수  범죄건수  인플루엔자 접종률  소비자물가지수(2020=100)  예금은행대출금액(십억원)  \
# 0      33      21  1688  8617       31.8              94.47       525529.0
# 1      33      21  1688  8617       31.8              94.47       525529.0
# 2      33      21  1688  8617       31.8              94.47       525529.0
# 3      33      21  1688  8617       31.8              94.47       525529.0
# 4      33      21  1688  8617       31.8              94.47       525529.0
#
#    예금은행예금액(십억원)  소비자물가 등락률(%)  임금상승률(%)  청년고용률(%)  실업률(시도)  실업자수(천명)  \
# ...

# %%
df2 = pd.read_csv('/content/drive/MyDrive/2조/Database/독립변수/성은/흡연율.csv', index_col=0)

df2 = df2.reset_index()


#df1에 '공공체육시설'이라는 칼럼을 추가하고, df2의 연도별, 지역구 조건에 맞는 데이터를 해당 칼럼에 넣는 함수
def add(df1, df2):
    # df2의 연도 열 이름을 리스트로 변환
    years = df2.columns[1:]

    # df2를 녹여서 각 지역구의 연도별 공공체육시설 수를 단일 열로 만듬
    df2_melted = df2.melt(id_vars=['지역구'], value_vars=years, var_name='계약년', value_name='흡연율(%)')
    df2_melted['계약년'] = df2_melted['계약년'].astype(int)  # 계약년 형변환

    # df1과 df2_melted를 '지역구'와 '계약년'을 기준으로 병합
    df1_merged = pd.merge(df1, df2_melted, on=['지역구', '계약년'], how='left')

    return df1_merged

#함수 실행
df1 = add(df1, df2)

#결과의 처음 몇 행 확인
print(df1.isnull().sum().sum())
df1.head()
# Out:
# 0
#    지역구    동             단지명  전용면적(㎡)  층  건축년도   계약년  계약월  계약일 거래금액(만원)  \
# 0  강남구  개포동  개포2차현대아파트(220)    77.75  5  1988  2015    1   11   60,000
# 1  강남구  개포동  개포2차현대아파트(220)    77.75  5  1988  2015    3    3   65,000
# 2  강남구  개포동  개포2차현대아파트(220)    77.75  2  1988  2015    3    7   62,500
# 3  강남구  개포동  개포2차현대아파트(220)    77.75  6  1988  2015    8   16   68,000
# 4  강남구  개포동  개포6차우성아파트1동~8동    79.97  5  1987  2015    1   29   73,000
#
#    초등학교 수  고등학교 수  학원 수  범죄건수  인플루엔자 접종률  소비자물가지수(2020=100)  예금은행대출금액(십억원)  \
# 0      33      21  1688  8617       31.8              94.47       525529.0
# 1      33      21  1688  8617       31.8              94.47       525529.0
# 2      33      21  1688  8617       31.8              94.47       525529.0
# 3      33      21  1688  8617       31.8              94.47       525529.0
# 4      33      21  1688  8617       31.8              94.47       525529.0
#
#    예금은행예금액(십억원)  소비자물가 등락률(%)  임금상승률(%)  청년고용률(%)  실업률(시도)  실업자수(천명)  \
# ...

# %%
df2 = pd.read_csv('/content/drive/MyDrive/2조/Database/독립변수/하은/건강보험+급여(구별).csv', index_col=0)

df2 = df2.reset_index()


#df1에 '공공체육시설'이라는 칼럼을 추가하고, df2의 연도별, 지역구 조건에 맞는 데이터를 해당 칼럼에 넣는 함수
def add(df1, df2):
    # df2의 연도 열 이름을 리스트로 변환
    years = df2.columns[1:]

    # df2를 녹여서 각 지역구의 연도별 공공체육시설 수를 단일 열로 만듬
    df2_melted = df2.melt(id_vars=['지역구'], value_vars=years, var_name='계약년', value_name='건강보험급여(천원)')
    df2_melted['계약년'] = df2_melted['계약년'].astype(int)  # 계약년 형변환

    # df1과 df2_melted를 '지역구'와 '계약년'을 기준으로 병합
    df1_merged = pd.merge(df1, df2_melted, on=['지역구', '계약년'], how='left')

    return df1_merged

#함수 실행
df1 = add(df1, df2)

#결과의 처음 몇 행 확인
print(df1.isnull().sum().sum())
df1.head()
# Out:
# 0
#    지역구    동             단지명  전용면적(㎡)  층  건축년도   계약년  계약월  계약일 거래금액(만원)  \
# 0  강남구  개포동  개포2차현대아파트(220)    77.75  5  1988  2015    1   11   60,000
# 1  강남구  개포동  개포2차현대아파트(220)    77.75  5  1988  2015    3    3   65,000
# 2  강남구  개포동  개포2차현대아파트(220)    77.75  2  1988  2015    3    7   62,500
# 3  강남구  개포동  개포2차현대아파트(220)    77.75  6  1988  2015    8   16   68,000
# 4  강남구  개포동  개포6차우성아파트1동~8동    79.97  5  1987  2015    1   29   73,000
#
#    초등학교 수  고등학교 수  학원 수  범죄건수  인플루엔자 접종률  소비자물가지수(2020=100)  예금은행대출금액(십억원)  \
# 0      33      21  1688  8617       31.8              94.47       525529.0
# 1      33      21  1688  8617       31.8              94.47       525529.0
# 2      33      21  1688  8617       31.8              94.47       525529.0
# 3      33      21  1688  8617       31.8              94.47       525529.0
# 4      33      21  1688  8617       31.8              94.47       525529.0
#
#    예금은행예금액(십억원)  소비자물가 등락률(%)  임금상승률(%)  청년고용률(%)  실업률(시도)  실업자수(천명)  \
# ...

# %%
# ???????????????????????????????????????
df2 = pd.read_csv('/content/drive/MyDrive/2조/Database/독립변수/승준/KOSPI지수(2015-2023).csv', index_col=0)
df2.head(20)

df2 = df2.reset_index()

df2
df2 = df2.T
df2 = df2.reset_index()

df2 = df2.T

df2

df2 = df2.reset_index(drop=True)
df2

df2.columns=['계약년', 'KOSPI지수']
df2

df2[['계약년도', '계약월']] = df2['계약년'].str.split('-', expand=True)

df2

df2 = df2.drop('계약년', axis=1)
df2.columns = ['KOSPI',	'계약월',	'계약년']


df2['계약년'] = df2['계약년'].astype('int64')
df2['계약년'] = df2['계약년']+2000

df2
# Out:
#         KOSPI 계약월   계약년
# 0    2,569.53  12  2023
# 1    2,535.29  11  2023
# 2    2,277.99  10  2023
# 3    2,465.07   9  2023
# 4    2,556.27   8  2023
# ..        ...  ..   ...
# 103  2,114.80   5  2015
# 104  2,127.17   4  2015
# 105  2,041.03   3  2015
# 106  1,985.80   2  2015
# 107  1,949.26   1  2015
#
# [108 rows x 3 columns]

# %%
df1['계약년'] = df1['계약년'].astype('int64')
df1['계약월'] = df1['계약월'].astype('int64')

# %%
df1.info()

df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 632731 entries, 0 to 632730
# Data columns (total 42 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   지역구                      632731 non-null  object
#  1   동                        632731 non-null  object
#  2   단지명                      632731 non-null  object
#  3   전용면적(㎡)                  632731 non-null  float64
#  4   층                        632731 non-null  int64
#  5   건축년도                     632731 non-null  int64
#  6   계약년                      632731 non-null  int64
#  7   계약월                      632731 non-null  int64
#  8   계약일                      632731 non-null  int64
#  9   거래금액(만원)                 632731 non-null  object
#  10  초등학교 수                   632731 non-null  int64
#  11  고등학교 수                   632731 non-null  int64
#  12  학원 수                     632731 non-null  int64
# ...

# %%
df2['계약월'] = df2['계약월'].astype('int64')

df1 = pd.merge(left=df1, right=df2, on=['계약년','계약월'])
df1.head()
# Out:
#    지역구    동         단지명  전용면적(㎡)   층  건축연도   계약년  계약월  계약일 거래금액(만원)  초등학교(개소)  \
# 0  강남구  개포동  성원대치2단지아파트  49.8600   4  1992  2022   12   23  104,000        33
# 1  강남구  개포동  성원대치2단지아파트  49.8600   4  1992  2022   12   23  104,000        33
# 2  강남구  개포동    디에이치아너힐즈  76.1709  24  2019  2022   12   22  220,000        33
# 3  강남구  개포동     개포주공6단지  83.2100   3  1983  2022   12   17  190,000        33
# 4  강남구  개포동     삼익대청아파트  51.1200  15  1992  2022   12   16  100,000        33
#
#    고등학교(개소)  학원(개소)  범죄건수(건)  인플루엔자 접종률(%)  서울시 소비자물가지수(2020=100)  \
# 0        22    2007     6947          47.9                 106.69
# 1        22    2007     6947          47.9                 106.69
# 2        22    2007     6947          47.9                 106.69
# 3        22    2007     6947          47.9                 106.69
# 4        22    2007     6947          47.9                 106.69
#
#    예금은행대출금액(십억원)  예금은행예금액(십억원)  소비자물가 등락률(%)  임금상승률(%)  청년고용률(%)  실업률(%)  \
# ...

# %%
df2 = pd.read_csv('/content/drive/MyDrive/2조/Database/독립변수/승준/공공체육시설(2010~2022)(수정).csv', index_col=0)

df2 = df2.reset_index()


#df1에 '공공체육시설'이라는 칼럼을 추가하고, df2의 연도별, 지역구 조건에 맞는 데이터를 해당 칼럼에 넣는 함수
def add(df1, df2):
    # df2의 연도 열 이름을 리스트로 변환
    years = df2.columns[1:]

    # df2를 녹여서 각 지역구의 연도별 공공체육시설 수를 단일 열로 만듬
    df2_melted = df2.melt(id_vars=['지역구'], value_vars=years, var_name='계약년', value_name='공공체육시설(개소)')
    df2_melted['계약년'] = df2_melted['계약년'].astype(int)  # 계약년 형변환

    # df1과 df2_melted를 '지역구'와 '계약년'을 기준으로 병합
    df1_merged = pd.merge(df1, df2_melted, on=['지역구', '계약년'], how='left')

    return df1_merged

#함수 실행
df1 = add(df1, df2)

#결과의 처음 몇 행 확인
print(df1.isnull().sum().sum())
df1.head()
# Out:
# 0
#    지역구    동             단지명  전용면적(㎡)  층  건축년도   계약년  계약월  계약일 거래금액(만원)  \
# 0  강남구  개포동  개포2차현대아파트(220)    77.75  5  1988  2015    1   11   60,000
# 1  강남구  개포동  개포2차현대아파트(220)    77.75  5  1988  2015    3    3   65,000
# 2  강남구  개포동  개포2차현대아파트(220)    77.75  2  1988  2015    3    7   62,500
# 3  강남구  개포동  개포2차현대아파트(220)    77.75  6  1988  2015    8   16   68,000
# 4  강남구  개포동  개포6차우성아파트1동~8동    79.97  5  1987  2015    1   29   73,000
#
#    초등학교 수  고등학교 수  학원 수  범죄건수  인플루엔자 접종률  소비자물가지수(2020=100)  예금은행대출금액(십억원)  \
# 0      33      21  1688  8617       31.8              94.47       525529.0
# 1      33      21  1688  8617       31.8              94.47       525529.0
# 2      33      21  1688  8617       31.8              94.47       525529.0
# 3      33      21  1688  8617       31.8              94.47       525529.0
# 4      33      21  1688  8617       31.8              94.47       525529.0
#
#    예금은행예금액(십억원)  소비자물가 등락률(%)  임금상승률(%)  청년고용률(%)  실업률(시도)  실업자수(천명)  \
# ...

# %%
df2 = pd.read_csv('/content/drive/MyDrive/2조/Database/독립변수/승준/공원(2010~2022)(수정본).csv', index_col=0, encoding='cp949')

df2 = df2.reset_index()


#df1에 '공공체육시설'이라는 칼럼을 추가하고, df2의 연도별, 지역구 조건에 맞는 데이터를 해당 칼럼에 넣는 함수
def add(df1, df2):
    # df2의 연도 열 이름을 리스트로 변환
    years = df2.columns[1:]

    # df2를 녹여서 각 지역구의 연도별 공공체육시설 수를 단일 열로 만듬
    df2_melted = df2.melt(id_vars=['지역구'], value_vars=years, var_name='계약년', value_name='공원면적(천㎡)')
    df2_melted['계약년'] = df2_melted['계약년'].astype(int)  # 계약년 형변환

    # df1과 df2_melted를 '지역구'와 '계약년'을 기준으로 병합
    df1_merged = pd.merge(df1, df2_melted, on=['지역구', '계약년'], how='left')

    return df1_merged

#함수 실행
df1 = add(df1, df2)

#결과의 처음 몇 행 확인
print(df1.isnull().sum().sum())
df1.head()
# Out:
# 0
#    지역구    동             단지명  전용면적(㎡)  층  건축년도   계약년  계약월  계약일 거래금액(만원)  \
# 0  강남구  개포동  개포2차현대아파트(220)    77.75  5  1988  2015    1   11   60,000
# 1  강남구  개포동  개포2차현대아파트(220)    77.75  5  1988  2015    3    3   65,000
# 2  강남구  개포동  개포2차현대아파트(220)    77.75  2  1988  2015    3    7   62,500
# 3  강남구  개포동  개포2차현대아파트(220)    77.75  6  1988  2015    8   16   68,000
# 4  강남구  개포동  개포6차우성아파트1동~8동    79.97  5  1987  2015    1   29   73,000
#
#    초등학교 수  고등학교 수  학원 수  범죄건수  인플루엔자 접종률  소비자물가지수(2020=100)  예금은행대출금액(십억원)  \
# 0      33      21  1688  8617       31.8              94.47       525529.0
# 1      33      21  1688  8617       31.8              94.47       525529.0
# 2      33      21  1688  8617       31.8              94.47       525529.0
# 3      33      21  1688  8617       31.8              94.47       525529.0
# 4      33      21  1688  8617       31.8              94.47       525529.0
#
#    예금은행예금액(십억원)  소비자물가 등락률(%)  임금상승률(%)  청년고용률(%)  실업률(시도)  실업자수(천명)  \
# ...

# %%
df2 = pd.read_csv('/content/drive/MyDrive/2조/Database/독립변수/승준/기준금리.csv', index_col=0, encoding='cp949')
df2

df2 = df2.reset_index()

df2
df2 = df2.T
df2 = df2.reset_index()
df2 = df2.T

df2
df2 = df2.reset_index(drop=True)
df2

df2 = df2.iloc[1:20, :]



df2['date'] = df2[0].astype(str) + '-' + df2[1].str[0:2] + '-' + df2[1].str[-3:-1]
df2['date'] = pd.to_datetime(df2['date'])

df2.head(20)
# df2.info()
# Out:
#        0        1     2       date
# 1   2022  11월 24일  3.25 2022-11-24
# 2   2022  10월 12일   3.0 2022-10-12
# 3   2022  08월 25일   2.5 2022-08-25
# 4   2022  07월 13일  2.25 2022-07-13
# 5   2022  05월 26일  1.75 2022-05-26
# 6   2022  04월 14일   1.5 2022-04-14
# 7   2022  01월 14일  1.25 2022-01-14
# 8   2021  11월 25일   1.0 2021-11-25
# 9   2021  08월 26일  0.75 2021-08-26
# 10  2020  05월 28일   0.5 2020-05-28
# 11  2020  03월 17일  0.75 2020-03-17
# 12  2019  10월 16일  1.25 2019-10-16
# 13  2019  07월 18일   1.5 2019-07-18
# 14  2018  11월 30일  1.75 2018-11-30
# 15  2017  11월 30일   1.5 2017-11-30
# 16  2016  06월 09일  1.25 2016-06-09
# 17  2015  06월 11일   1.5 2015-06-11
# 18  2015  03월 12일  1.75 2015-03-12
# 19  2014  10월 15일   2.0 2014-10-15

# %%
df2['date'].min()
df2['date'].max()
# Out:
# Timestamp('2022-11-24 00:00:00')

# %%
di = pd.date_range(start='2014-01-01', end='2023-12-31')

# %%
import numpy as np

# %%
def matching(x):
  for idx, val in df2.iterrows():
    if x >= val.date:
      return val[2]
  return np.nan

interest = pd.DataFrame(di)
interest['기준금리'] = pd.DataFrame(di)[0].apply(matching)
interest = interest.set_index(0)
interest['계약년'] = interest.index.year
interest['계약월'] = interest.index.month
interest['계약일'] = interest.index.day
interest
# Out:
#             기준금리   계약년  계약월  계약일
# 0
# 2014-01-01   NaN  2014    1    1
# 2014-01-02   NaN  2014    1    2
# 2014-01-03   NaN  2014    1    3
# 2014-01-04   NaN  2014    1    4
# 2014-01-05   NaN  2014    1    5
# ...          ...   ...  ...  ...
# 2023-12-27  3.25  2023   12   27
# 2023-12-28  3.25  2023   12   28
# 2023-12-29  3.25  2023   12   29
# 2023-12-30  3.25  2023   12   30
# 2023-12-31  3.25  2023   12   31
#
# [3652 rows x 4 columns]

# %%
df1 = pd.merge(left=df1, right=interest, on=['계약년', '계약월', '계약일'] )
df1 = df1.sort_values(['계약년', '계약월', '계약일'], ascending=False)
df1.head()
# Out:
#     지역구     동             단지명  전용면적(㎡)   층  건축년도   계약년  계약월  계약일 거래금액(만원)  \
# 0   강남구   대치동              은마  76.7900   2  1979  2022   12   31  184,000
# 1   강서구   마곡동  마곡13단지힐스테이트마스터  84.9805  15  2017  2022   12   31  113,500
# 2   구로구  신도림동           디큐브시티  59.8800   4  2011  2022   12   31   85,000
# 3   노원구   상계동      상계주공12(고층)  41.3000  12  1988  2022   12   31   39,000
# 4  동대문구   용두동        래미안 허브리츠  59.9800  12  2011  2022   12   31   80,000
#
#    초등학교 수  고등학교 수  학원 수  범죄건수  인플루엔자 접종률  소비자물가지수(2020=100)  예금은행대출금액(십억원)  \
# 0      33      22  2007  6947       47.9             106.69       871747.0
# 1      35      23   661  4663       44.0             106.69       871747.0
# 2      26      14   352  3857       36.1             106.69       871747.0
# 3      42      25   674  3896       40.3             106.69       871747.0
# 4      21      11   329  3253       43.2             106.69       871747.0
#
# ...

# %%
print(df1.isnull().sum())
# Out:
# 지역구                        0
# 동                          0
# 단지명                        0
# 전용면적(㎡)                    0
# 층                          0
# 건축년도                       0
# 계약년                        0
# 계약월                        0
# 계약일                        0
# 거래금액(만원)                   0
# 초등학교 수                     0
# 고등학교 수                     0
# 학원 수                       0
# 범죄건수                       0
# 인플루엔자 접종률                  0
# 소비자물가지수(2020=100)          0
# 예금은행대출금액(십억원)              0
# 예금은행예금액(십억원)               0
# 소비자물가 등락률(%)               0
# 임금상승률(%)                   0
# 청년고용률(%)                   0
# 실업률(시도)                    0
# 실업자수(천명)                   0
# 취업자증감(천명)                  0
# 청년실업률(%)                   0
# 제조업생산 증감률(%)               0
# 서비스업생산 증감률(%)              0
# 수입액(100만달러)                0
# 수출액(100만달러)                0
# 지방세(백만원)                   0
# 국내총생산(명목GDP)               0
# 경제성장률(실질GDP성장률)            0
# ...

# %%
df1 = df1.sort_values(['지역구', '동']).reset_index(drop=True)
df1.head(30)
# Out:
#     지역구    동          단지명   전용면적(㎡)   층  건축년도   계약년  계약월  계약일 거래금액(만원)  \
# 0   강남구  개포동   성원대치2단지아파트   49.8600   4  1992  2022   12   23  104,000
# 1   강남구  개포동   성원대치2단지아파트   49.8600   4  1992  2022   12   23  104,000
# 2   강남구  개포동     디에이치아너힐즈   76.1709  24  2019  2022   12   22  220,000
# 3   강남구  개포동      개포주공6단지   83.2100   3  1983  2022   12   17  190,000
# 4   강남구  개포동      삼익대청아파트   51.1200  15  1992  2022   12   16  100,000
# 5   강남구  개포동     래미안블레스티지   84.9430   8  2019  2022   12    5  241,000
# 6   강남구  개포동    개포래미안포레스트   84.8600   5  2020  2022   11   29  240,000
# 7   강남구  개포동     디에이치아너힐즈   84.3558  19  2019  2022   11   26  250,000
# 8   강남구  개포동    개포래미안포레스트   84.8300  33  2020  2022   11   25  240,000
# 9   강남구  개포동   성원대치2단지아파트   33.1800  13  1992  2022   11   16   84,700
# 10  강남구  개포동   성원대치2단지아파트   39.5300   3  1992  2022   11   15  102,500
# 11  강남구  개포동      삼익대청아파트   60.0000   7  1992  2022   11   14  134,000
# ...

# %%
df2 = pd.read_csv('/content/drive/MyDrive/2조/Database/독립변수/승준/소비자물가지수(2015-2023).csv', index_col=0)
df2 = df2.reset_index()
df2 = df2.T
df2 = df2.reset_index()
df2 = df2.T
df2 = df2.reset_index(drop=True)
df2

df2.columns=['계약연월', '소비자물가지수']
df2

df2[['계약년도', '계약월']] = df2['계약연월'].str.split('. ', expand=True)
df2

df2 = df2.drop('계약연월', axis=1)
df2

df2.columns = ['소비자물가지수',	'계약년',	'계약월']
df2

df2.info()
df2['계약년'] = df2['계약년'].astype('int64')
df2['계약월'] = df2['계약월'].astype('int64')

df2.info()

df1 = pd.merge(left=df1, right=df2, on=['계약년', '계약월'])
df1.isnull().sum().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   소비자물가지수  105 non-null    object
#  1   계약년        105 non-null    object
#  2   계약월        105 non-null    object
# dtypes: object(3)
# memory usage: 2.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   소비자물가지수  105 non-null    object
#  1   계약년        105 non-null    int64
#  2   계약월        105 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 2.6+ KB
# 0

# %%
df2 = pd.read_csv('/content/drive/MyDrive/2조/Database/독립변수/승준/시내주요기관(경찰,소방관서)(수정본).csv', index_col=0)
df2 = df2.dropna()
df2 = df2.reset_index()


#df1에 '공공체육시설'이라는 칼럼을 추가하고, df2의 연도별, 지역구 조건에 맞는 데이터를 해당 칼럼에 넣는 함수
def add(df1, df2):
    # df2의 연도 열 이름을 리스트로 변환
    years = df2.columns[1:]

    # df2를 녹여서 각 지역구의 연도별 공공체육시설 수를 단일 열로 만듬
    df2_melted = df2.melt(id_vars=['지역구'], value_vars=years, var_name='계약년', value_name='시내주요기관(경찰, 소방관서)')
    df2_melted['계약년'] = df2_melted['계약년'].astype(int)  # 계약년 형변환

    # df1과 df2_melted를 '지역구'와 '계약년'을 기준으로 병합
    df1_merged = pd.merge(df1, df2_melted, on=['지역구', '계약년'], how='left')

    return df1_merged

#함수 실행
df1 = add(df1, df2)

#결과의 처음 몇 행 확인
print(df1.isnull().sum().sum())
df1.head()
# Out:
# 0
#    지역구    동         단지명  전용면적(㎡)   층  건축년도   계약년  계약월  계약일 거래금액(만원)  초등학교 수  \
# 0  강남구  개포동  성원대치2단지아파트  49.8600   4  1992  2022   12   23  104,000      33
# 1  강남구  개포동  성원대치2단지아파트  49.8600   4  1992  2022   12   23  104,000      33
# 2  강남구  개포동    디에이치아너힐즈  76.1709  24  2019  2022   12   22  220,000      33
# 3  강남구  개포동     개포주공6단지  83.2100   3  1983  2022   12   17  190,000      33
# 4  강남구  개포동     삼익대청아파트  51.1200  15  1992  2022   12   16  100,000      33
#
#    고등학교 수  학원 수  범죄건수  인플루엔자 접종률  소비자물가지수(2020=100)  예금은행대출금액(십억원)  \
# 0      22  2007  6947       47.9             106.69       871747.0
# 1      22  2007  6947       47.9             106.69       871747.0
# 2      22  2007  6947       47.9             106.69       871747.0
# 3      22  2007  6947       47.9             106.69       871747.0
# 4      22  2007  6947       47.9             106.69       871747.0
#
#    예금은행예금액(십억원)  소비자물가 등락률(%)  임금상승률(%)  청년고용률(%)  실업률(시도)  실업자수(천명)  \
# ...

# %%
df2 = pd.read_csv('/content/drive/MyDrive/2조/Database/독립변수/승준/의료기관(2010~2022).csv', index_col=0)
df2 = df2.reset_index()


#df1에 '공공체육시설'이라는 칼럼을 추가하고, df2의 연도별, 지역구 조건에 맞는 데이터를 해당 칼럼에 넣는 함수
def add(df1, df2):
    # df2의 연도 열 이름을 리스트로 변환
    years = df2.columns[1:]

    # df2를 녹여서 각 지역구의 연도별 공공체육시설 수를 단일 열로 만듬
    df2_melted = df2.melt(id_vars=['지역구'], value_vars=years, var_name='계약년', value_name='시내주요기관(경찰, 소방관서)')
    df2_melted['계약년'] = df2_melted['계약년'].astype(int)  # 계약년 형변환

    # df1과 df2_melted를 '지역구'와 '계약년'을 기준으로 병합
    df1_merged = pd.merge(df1, df2_melted, on=['지역구', '계약년'], how='left')

    return df1_merged

#함수 실행
df1 = add(df1, df2)

#결과의 처음 몇 행 확인
print(df1.isnull().sum().sum())
df1.head()
# Out:
# 0
#    지역구    동         단지명  전용면적(㎡)   층  건축년도   계약년  계약월  계약일 거래금액(만원)  초등학교 수  \
# 0  강남구  개포동  성원대치2단지아파트  49.8600   4  1992  2022   12   23  104,000      33
# 1  강남구  개포동  성원대치2단지아파트  49.8600   4  1992  2022   12   23  104,000      33
# 2  강남구  개포동    디에이치아너힐즈  76.1709  24  2019  2022   12   22  220,000      33
# 3  강남구  개포동     개포주공6단지  83.2100   3  1983  2022   12   17  190,000      33
# 4  강남구  개포동     삼익대청아파트  51.1200  15  1992  2022   12   16  100,000      33
#
#    고등학교 수  학원 수  범죄건수  인플루엔자 접종률  소비자물가지수(2020=100)  예금은행대출금액(십억원)  \
# 0      22  2007  6947       47.9             106.69       871747.0
# 1      22  2007  6947       47.9             106.69       871747.0
# 2      22  2007  6947       47.9             106.69       871747.0
# 3      22  2007  6947       47.9             106.69       871747.0
# 4      22  2007  6947       47.9             106.69       871747.0
#
#    예금은행예금액(십억원)  소비자물가 등락률(%)  임금상승률(%)  청년고용률(%)  실업률(시도)  실업자수(천명)  \
# ...

# %%
df1.rename(columns = {'시내주요기관(경찰, 소방관서)_x':'시내주요기관(경찰, 소방관서)', '시내주요기관(경찰, 소방관서)_y':'전체병원(개소)'}, inplace=True)
df1.head()
# Out:
#    지역구    동         단지명  전용면적(㎡)   층  건축년도   계약년  계약월  계약일 거래금액(만원)  초등학교 수  \
# 0  강남구  개포동  성원대치2단지아파트  49.8600   4  1992  2022   12   23  104,000      33
# 1  강남구  개포동  성원대치2단지아파트  49.8600   4  1992  2022   12   23  104,000      33
# 2  강남구  개포동    디에이치아너힐즈  76.1709  24  2019  2022   12   22  220,000      33
# 3  강남구  개포동     개포주공6단지  83.2100   3  1983  2022   12   17  190,000      33
# 4  강남구  개포동     삼익대청아파트  51.1200  15  1992  2022   12   16  100,000      33
#
#    고등학교 수  학원 수  범죄건수  인플루엔자 접종률  소비자물가지수(2020=100)  예금은행대출금액(십억원)  \
# 0      22  2007  6947       47.9             106.69       871747.0
# 1      22  2007  6947       47.9             106.69       871747.0
# 2      22  2007  6947       47.9             106.69       871747.0
# 3      22  2007  6947       47.9             106.69       871747.0
# 4      22  2007  6947       47.9             106.69       871747.0
#
#    예금은행예금액(십억원)  소비자물가 등락률(%)  임금상승률(%)  청년고용률(%)  실업률(시도)  실업자수(천명)  \
# ...

# %%
df2 = pd.read_csv('/content/drive/MyDrive/2조/Database/독립변수/승준/종합의료기관(2010~2022).csv', index_col=0)
df2 = df2.reset_index()


#df1에 '공공체육시설'이라는 칼럼을 추가하고, df2의 연도별, 지역구 조건에 맞는 데이터를 해당 칼럼에 넣는 함수
def add(df1, df2):
    # df2의 연도 열 이름을 리스트로 변환
    years = df2.columns[1:]

    # df2를 녹여서 각 지역구의 연도별 공공체육시설 수를 단일 열로 만듬
    df2_melted = df2.melt(id_vars=['지역구'], value_vars=years, var_name='계약년', value_name='종합병원(개소)')
    df2_melted['계약년'] = df2_melted['계약년'].astype(int)  # 계약년 형변환

    # df1과 df2_melted를 '지역구'와 '계약년'을 기준으로 병합
    df1_merged = pd.merge(df1, df2_melted, on=['지역구', '계약년'], how='left')

    return df1_merged

#함수 실행
df1 = add(df1, df2)

#결과의 처음 몇 행 확인
print(df1.isnull().sum().sum())
df1.head()
# Out:
# 0
#    지역구    동         단지명  전용면적(㎡)   층  건축년도   계약년  계약월  계약일 거래금액(만원)  초등학교 수  \
# 0  강남구  개포동  성원대치2단지아파트  49.8600   4  1992  2022   12   23  104,000      33
# 1  강남구  개포동  성원대치2단지아파트  49.8600   4  1992  2022   12   23  104,000      33
# 2  강남구  개포동    디에이치아너힐즈  76.1709  24  2019  2022   12   22  220,000      33
# 3  강남구  개포동     개포주공6단지  83.2100   3  1983  2022   12   17  190,000      33
# 4  강남구  개포동     삼익대청아파트  51.1200  15  1992  2022   12   16  100,000      33
#
#    고등학교 수  학원 수  범죄건수  인플루엔자 접종률  소비자물가지수(2020=100)  예금은행대출금액(십억원)  \
# 0      22  2007  6947       47.9             106.69       871747.0
# 1      22  2007  6947       47.9             106.69       871747.0
# 2      22  2007  6947       47.9             106.69       871747.0
# 3      22  2007  6947       47.9             106.69       871747.0
# 4      22  2007  6947       47.9             106.69       871747.0
#
#    예금은행예금액(십억원)  소비자물가 등락률(%)  임금상승률(%)  청년고용률(%)  실업률(시도)  실업자수(천명)  \
# ...

# %%
df1.columns
# Out:
# Index(['지역구', '동', '단지명', '전용면적(㎡)', '층', '건축년도', '계약년', '계약월', '계약일',
#        '거래금액(만원)', '초등학교 수', '고등학교 수', '학원 수', '범죄건수', '인플루엔자 접종률',
#        '소비자물가지수(2020=100)', '예금은행대출금액(십억원)', '예금은행예금액(십억원)', '소비자물가 등락률(%)',
#        '임금상승률(%)', '청년고용률(%)', '실업률(시도)', '실업자수(천명)', '취업자증감(천명)', '청년실업률(%)',
#        '제조업생산 증감률(%)', '서비스업생산 증감률(%)', '수입액(100만달러)', '수출액(100만달러)',
#        '지방세(백만원)', '국내총생산(명목GDP)', '경제성장률(실질GDP성장률)', '건강생활실천율', '연간출산률',
#        '노인여가복지시설', '등록외국인현황(명)', '비만율(%)', '월간음주율(%)',
#        '다문화가구(가구)', '다문화가구원(명)', '흡연율(%)', '건강보험급여(천원)',
#        '공공체육시설(개소)', '공원면적(천㎡)', '기준금리', '소비자물가지수', '시내주요기관(경찰, 소방관서)',
#        '전체병원(개소)', '종합병원(개소)'],
#       dtype='object')

# %%
df1.columns = ['지역구', '동', '단지명', '전용면적(㎡)', '층', '건축연도', '계약년', '계약월', '계약일',
       '거래금액(만원)', '초등학교(개소)', '고등학교(개소)', '학원(개소)', '범죄건수(건)', '인플루엔자 접종률(%)',
       '서울시 소비자물가지수(2020=100)', '예금은행대출금액(십억원)', '예금은행예금액(십억원)', '소비자물가 등락률(%)',
       '임금상승률(%)', '청년고용률(%)', '실업률(%)', '실업자수(천명)', '취업자증감(천명)', '청년실업률(%)',
       '제조업생산 증감률(%)', '서비스업생산 증감률(%)', '수입액(백만달러)', '수출액(백만달러)',
       '지방세(백만원)', '국내총생산(명목GDP,십억원)', '경제성장률(실질GDP성장률,%)', '건강생활실천율(%)', '연간출산률(%)',
       '노인여가복지시설(개소)', '등록외국인현황(명)', '비만율(%)', '월간음주율(%)',
       '다문화가구(가구)', '다문화가구원(명)', '흡연율(%)', '건강보험급여(천원)',
       '공공체육시설(개소)', '공원면적(천㎡)', '기준금리(%)', '전국 소비자물가지수(2020=100)', '경찰 및 소방관서(개소)',
       '전체병원(개소)', '종합병원(개소)']

# %%
df1.head()
# Out:
#    지역구    동         단지명  전용면적(㎡)   층  건축연도   계약년  계약월  계약일 거래금액(만원)  초등학교(개소)  \
# 0  강남구  개포동  성원대치2단지아파트  49.8600   4  1992  2022   12   23  104,000        33
# 1  강남구  개포동  성원대치2단지아파트  49.8600   4  1992  2022   12   23  104,000        33
# 2  강남구  개포동    디에이치아너힐즈  76.1709  24  2019  2022   12   22  220,000        33
# 3  강남구  개포동     개포주공6단지  83.2100   3  1983  2022   12   17  190,000        33
# 4  강남구  개포동     삼익대청아파트  51.1200  15  1992  2022   12   16  100,000        33
#
#    고등학교(개소)  학원(개소)  범죄건수(건)  인플루엔자 접종률(%)  서울시 소비자물가지수(2020=100)  \
# 0        22    2007     6947          47.9                 106.69
# 1        22    2007     6947          47.9                 106.69
# 2        22    2007     6947          47.9                 106.69
# 3        22    2007     6947          47.9                 106.69
# 4        22    2007     6947          47.9                 106.69
#
#    예금은행대출금액(십억원)  예금은행예금액(십억원)  소비자물가 등락률(%)  임금상승률(%)  청년고용률(%)  실업률(%)  \
# ...

# %%
df1.columns
# Out:
# Index(['지역구', '동', '단지명', '전용면적(㎡)', '층', '건축연도', '계약년', '계약월', '계약일',
#        '거래금액(만원)', '초등학교(개소)', '고등학교(개소)', '학원(개소)', '범죄건수(건)', '인플루엔자 접종률(%)',
#        '서울시 소비자물가지수(2020=100)', '예금은행대출금액(십억원)', '예금은행예금액(십억원)',
#        '소비자물가 등락률(%)', '임금상승률(%)', '청년고용률(%)', '실업률(%)', '실업자수(천명)',
#        '취업자증감(천명)', '청년실업률(%)', '제조업생산 증감률(%)', '서비스업생산 증감률(%)', '수입액(백만달러)',
#        '수출액(백만달러)', '지방세(백만원)', '국내총생산(명목GDP,십억원)', '경제성장률(실질GDP성장률,%)',
#        '건강생활실천율(%)', '연간출산률(%)', '노인여가복지시설(개소)',
#        '등록외국인현황(명)', '비만율(%)', '월간음주율(%)', '다문화가구(가구)',
#        '다문화가구원(명)', '흡연율(%)', '건강보험급여(천원)', '공공체육시설(개소)', '공원면적(천㎡)',
#        '기준금리(%)', '전국 소비자물가지수(2020=100)', '경찰 및 소방관서(개소)', '전체병원(개소)',
#        '종합병원(개소)', 'KOSPI'],
#       dtype='object')

# %%
df1 = df1[[
         # 아파트 자체 특성
        '지역구', '동', '계약년', '계약월', '계약일', '전용면적(㎡)', '층', '건축연도',
         # 환경 특성
         '공공체육시설(개소)', '공원면적(천㎡)', '경찰 및 소방관서(개소)', '전체병원(개소)', '종합병원(개소)', '노인여가복지시설(개소)', '초등학교(개소)', '고등학교(개소)', '학원(개소)', '범죄건수(건)',
         # 경제 특성
        'KOSPI', '전국 소비자물가지수(2020=100)', '서울시 소비자물가지수(2020=100)', '소비자물가 등락률(%)', '임금상승률(%)', '건강보험급여(천원)', '기준금리(%)', '예금은행대출금액(십억원)', '예금은행예금액(십억원)',
       '제조업생산 증감률(%)', '서비스업생산 증감률(%)', '수입액(백만달러)', '수출액(백만달러)', '지방세(백만원)', '국내총생산(명목GDP,십억원)', '경제성장률(실질GDP성장률,%)',
         # 취업
        '청년고용률(%)', '청년실업률(%)', '실업률(%)', '실업자수(천명)', '취업자증감(천명)',
         # 건강
         '흡연율(%)', '월간음주율(%)', '비만율(%)', '건강생활실천율(%)', '인플루엔자 접종률(%)',
         # 인구
       '연간출산률(%)', '등록외국인현황(명)', '다문화가구(가구)', '다문화가구원(명)',
         # 종속변수
         '거래금액(만원)', ]]

# %%
df1
# Out:
#         지역구    동   계약년  계약월  계약일  전용면적(㎡)   층  건축연도  공공체육시설(개소)  공원면적(천㎡)  \
# 0       강남구  개포동  2022   12   23  49.8600   4  1992         293    7794.1
# 1       강남구  개포동  2022   12   23  49.8600   4  1992         293    7794.1
# 2       강남구  개포동  2022   12   22  76.1709  24  2019         293    7794.1
# 3       강남구  개포동  2022   12   17  83.2100   3  1983         293    7794.1
# 4       강남구  개포동  2022   12   16  51.1200  15  1992         293    7794.1
# ...     ...  ...   ...  ...  ...      ...  ..   ...         ...       ...
# 632726  중랑구  중화동  2015    1    8  59.7600  20  1997         108    5233.0
# 632727  중랑구  중화동  2015    1    7  59.7600   8  1997         108    5233.0
# 632728  중랑구  중화동  2015    1    6  84.8900   2  1991         108    5233.0
# 632729  중랑구  중화동  2015    1    6  84.3500   7  2010         108    5233.0
# 632730  중랑구  중화동  2015    1    5  84.0300  20  1997         108    5233.0
#
#         경찰 및 소방관서(개소)  전체병원(개소)  종합병원(개소)  노인여가복지시설(개소)  초등학교(개소)  \
# ...

# %%
pd.options.display.float_format = '{:.2f}'.format
df1.head()
# Out:
#    지역구    동   계약년  계약월  계약일  전용면적(㎡)   층  건축연도  공공체육시설(개소)  공원면적(천㎡)  \
# 0  강남구  개포동  2022   12   23    49.86   4  1992         293   7794.10
# 1  강남구  개포동  2022   12   23    49.86   4  1992         293   7794.10
# 2  강남구  개포동  2022   12   22    76.17  24  2019         293   7794.10
# 3  강남구  개포동  2022   12   17    83.21   3  1983         293   7794.10
# 4  강남구  개포동  2022   12   16    51.12  15  1992         293   7794.10
#
#    경찰 및 소방관서(개소)  전체병원(개소)  종합병원(개소)  노인여가복지시설(개소)  초등학교(개소)  \
# 0          30.00      2815         3                      184        33
# 1          30.00      2815         3                      184        33
# 2          30.00      2815         3                      184        33
# 3          30.00      2815         3                      184        33
# 4          30.00      2815         3                      184        33
#
#    고등학교(개소)  학원(개소)  범죄건수(건)     KOSPI 전국 소비자물가지수(2020=100)  \
# ...

# %%
df1.rename(columns = {'연간출산률(%)': '연간출산율(%)'}, inplace=True)
df1
# Out:
#         지역구    동   계약년  계약월  계약일  전용면적(㎡)   층  건축연도  공공체육시설(개소)  공원면적(천㎡)  \
# 0       강남구  개포동  2022   12   23    49.86   4  1992         293   7794.10
# 1       강남구  개포동  2022   12   23    49.86   4  1992         293   7794.10
# 2       강남구  개포동  2022   12   22    76.17  24  2019         293   7794.10
# 3       강남구  개포동  2022   12   17    83.21   3  1983         293   7794.10
# 4       강남구  개포동  2022   12   16    51.12  15  1992         293   7794.10
# ...     ...  ...   ...  ...  ...      ...  ..   ...         ...       ...
# 632726  중랑구  중화동  2015    1    8    59.76  20  1997         108   5233.00
# 632727  중랑구  중화동  2015    1    7    59.76   8  1997         108   5233.00
# 632728  중랑구  중화동  2015    1    6    84.89   2  1991         108   5233.00
# 632729  중랑구  중화동  2015    1    6    84.35   7  2010         108   5233.00
# 632730  중랑구  중화동  2015    1    5    84.03  20  1997         108   5233.00
#
#         경찰 및 소방관서(개소)  전체병원(개소)  종합병원(개소)  노인여가복지시설(개소)  초등학교(개소)  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 632731 entries, 0 to 632730
# Data columns (total 49 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   지역구                      632731 non-null  object
#  1   동                        632731 non-null  object
#  2   계약년                      632731 non-null  int64
#  3   계약월                      632731 non-null  int64
#  4   계약일                      632731 non-null  int64
#  5   전용면적(㎡)                  632731 non-null  float64
#  6   층                        632731 non-null  int64
#  7   건축연도                     632731 non-null  int64
#  8   공공체육시설(개소)               632731 non-null  int64
#  9   공원면적(천㎡)                 632731 non-null  float64
#  10  경찰 및 소방관서(개소)            632731 non-null  float64
#  11  전체병원(개소)                 632731 non-null  int64
#  12  종합병원(개소)                 632731 non-null  int64
# ...

# %%
df1['KOSPI'] = df1['KOSPI'].str.replace(',', '')

# %%
df1['국내총생산(명목GDP,십억원)'] = df1['국내총생산(명목GDP,십억원)'].str.replace(',', '')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 632731 entries, 0 to 632730
# Data columns (total 49 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   지역구                      632731 non-null  object
#  1   동                        632731 non-null  object
#  2   계약년                      632731 non-null  int64
#  3   계약월                      632731 non-null  int64
#  4   계약일                      632731 non-null  int64
#  5   전용면적(㎡)                  632731 non-null  float64
#  6   층                        632731 non-null  int64
#  7   건축연도                     632731 non-null  int64
#  8   공공체육시설(개소)               632731 non-null  int64
#  9   공원면적(천㎡)                 632731 non-null  float64
#  10  경찰 및 소방관서(개소)            632731 non-null  float64
#  11  전체병원(개소)                 632731 non-null  int64
#  12  종합병원(개소)                 632731 non-null  int64
# ...

# %%
df1['거래금액(만원)'] = df1['거래금액(만원)'].str.replace(',', '')

# %%
df1['거래금액(만원)'] = df1['거래금액(만원)'].astype('int64')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 632731 entries, 0 to 632730
# Data columns (total 49 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   지역구                      632731 non-null  object
#  1   동                        632731 non-null  object
#  2   계약년                      632731 non-null  int64
#  3   계약월                      632731 non-null  int64
#  4   계약일                      632731 non-null  int64
#  5   전용면적(㎡)                  632731 non-null  float64
#  6   층                        632731 non-null  int64
#  7   건축연도                     632731 non-null  int64
#  8   공공체육시설(개소)               632731 non-null  int64
#  9   공원면적(천㎡)                 632731 non-null  float64
#  10  경찰 및 소방관서(개소)            632731 non-null  float64
#  11  전체병원(개소)                 632731 non-null  int64
#  12  종합병원(개소)                 632731 non-null  int64
# ...

# %%
df1.head()
# Out:
#    지역구    동   계약년  계약월  계약일  전용면적(㎡)   층  건축연도  공공체육시설(개소)  공원면적(천㎡)  \
# 0  강남구  개포동  2022   12   23    49.86   4  1992         293   7794.10
# 1  강남구  개포동  2022   12   23    49.86   4  1992         293   7794.10
# 2  강남구  개포동  2022   12   22    76.17  24  2019         293   7794.10
# 3  강남구  개포동  2022   12   17    83.21   3  1983         293   7794.10
# 4  강남구  개포동  2022   12   16    51.12  15  1992         293   7794.10
#
#    경찰 및 소방관서(개소)  전체병원(개소)  종합병원(개소)  노인여가복지시설(개소)  초등학교(개소)  \
# 0          30.00      2815         3                      184        33
# 1          30.00      2815         3                      184        33
# 2          30.00      2815         3                      184        33
# 3          30.00      2815         3                      184        33
# 4          30.00      2815         3                      184        33
#
#    고등학교(개소)  학원(개소)  범죄건수(건)   KOSPI  전국 소비자물가지수(2020=100)  \
# ...

# %%
df1.to_csv('data(ver.4.1)_한솔.csv')
